# %% [markdown]
# # Segmenting and Clustering Toronto

# %% [markdown]
# ### First section
#
# We will first start by importing data from the Wikipedia site into a Dataframe per specifications

# %%
#install BeautifulSoup and import library

# !conda install beautifulsoup4

from bs4 import BeautifulSoup
import requests
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.0-py35h442a8c9_1 --> 4.6.3-py35_0
#
# beautifulsoup4 100% |################################| Time: 0:00:00  30.98 MB/s

# %%
#start parsing the website
import urllib.request as urllib2

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

with urllib2.urlopen(url) as html_file:
    soup = BeautifulSoup(html_file)

# %%
#import data processing libraries and create Dataframe
import pandas as pd
import numpy as np

table = soup.find('table', class_='wikitable sortable')
df = pd.read_html(str(table), header = 0)[0]
df.rename(columns={'Postcode':'Postalcode'}, inplace=True)

#Clean NA Borough values
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.dropna(subset=['Borough'], axis = 0, inplace=True)
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#   Postalcode           Borough     Neighbourhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights

# %%
#For NA neighbourhoods, fill with Borough
df['Neighbourhood'].replace('Not assigned', df['Borough'], inplace=True)
df.head(10)
# Out:
#   Postalcode           Borough     Neighbourhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights
# 5        M6A        North York    Lawrence Manor
# 6        M7A      Queen's Park      Queen's Park
# 7        M9A         Etobicoke  Islington Avenue
# 8        M1B       Scarborough             Rouge
# 9        M1B       Scarborough           Malvern

# %%
#For more than one Postcode, combine neighbourhoods
df_grouped = df.groupby(['Postalcode','Borough'])[['Neighbourhood']].agg(lambda col: ', '.join(col))
df_grouped.reset_index(inplace=True)
df_grouped.head(10)
# Out:
#   Postalcode      Borough                                    Neighbourhood
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West

# %% [markdown]
# ## Using Geocoder to obtain Latitude and Longitude for each Postalcode

# %%
#import geocoder library
# !pip install geocoder
import geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 6.5MB/s ta 0:00:01
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: future in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: click in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: decorator in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ratelim->geocoder)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
#Getting lists for longitude and latitude using ArcGIS (World Geocoding Service)

latitude = []
longitude = []

for index, row in df_grouped.iterrows():
    while True:
        g = geocoder.arcgis('%s, Toronto, Ontario' % row['Postalcode'])
        latitude.append(g.lat)
        longitude.append(g.lng)
        if latitude[index] != None:
            break

# %%
#Adding columns

df_grouped['Latitude'] = latitude
df_grouped['Longitude'] = longitude

# %%
df_grouped.head(10)
# Out:
#   Postalcode      Borough                                    Neighbourhood  \
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.811650 -79.195561
# 1  43.785605 -79.158701
# 2  43.765690 -79.175299
# 3  43.768216 -79.217610
# 4  43.769608 -79.239440
# 5  43.743085 -79.232172
# 6  43.726260 -79.263670
# 7  43.713213 -79.284910
# 8  43.723575 -79.234976
# 9  43.696690 -79.260069

# %% [markdown]
# #### After having ready the Dataframe, we continue to graph the Borough's centers to determine which ones to analyze

# %%
#Getting Borough centers to map them and decide which Neighbourhoods to analyze

new_df = df_grouped.groupby('Borough')['Latitude','Longitude'].mean()
new_df.reset_index(inplace=True)
new_df
# Out:
#              Borough   Latitude  Longitude
# 0    Central Toronto  43.701806 -79.398985
# 1   Downtown Toronto  43.654154 -79.384989
# 2       East Toronto  43.667847 -79.337088
# 3          East York  43.699376 -79.333363
# 4          Etobicoke  43.660150 -79.539829
# 5        Mississauga  43.648690 -79.385440
# 6         North York  43.751070 -79.429470
# 7       Queen's Park  43.661072 -79.390895
# 8        Scarborough  43.767385 -79.248044
# 9       West Toronto  43.651699 -79.444922
# 10              York  43.691192 -79.473105

# %%
#Import folium library to map Toronto's Boroughs

# !conda install folium -c conda-forge
import folium

map1 = folium.Map(location=[43.65,-79.38], zoom_start=11)

for lat, lng, label in zip(new_df['Latitude'], new_df['Longitude'], new_df['Borough']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map1)  
    
map1
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.6.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00   3.02 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  27.98 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  24.22 MB/s
# folium-0.6.0-p 100% |################################| Time: 0:00:00  33.33 MB/s
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### After reading the map we determine that Toronto center would be an interesting area to analyze. This is reduced to filtering all Boroughs with 'Toronto' in them.
#
# ##### We create a new Dataframe with the data to analyze.

# %%
df_toronto = df_grouped[df_grouped['Borough'].apply(lambda x: 'Toronto' in x)]
df_toronto.head(10)
# Out:
#    Postalcode          Borough  \
# 37        M4E     East Toronto
# 41        M4K     East Toronto
# 42        M4L     East Toronto
# 43        M4M     East Toronto
# 44        M4N  Central Toronto
# 45        M4P  Central Toronto
# 46        M4R  Central Toronto
# 47        M4S  Central Toronto
# 48        M4T  Central Toronto
# 49        M4V  Central Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 37                                        The Beaches  43.676531 -79.295410
# 41                       The Danforth West, Riverdale  43.683262 -79.355120
# 42                     The Beaches West, India Bazaar  43.667985 -79.314642
# 43                                    Studio District  43.662766 -79.334830
# 44                                      Lawrence Park  43.728135 -79.387090
# 45                                   Davisville North  43.712755 -79.388514
# 46                                 North Toronto West  43.714523 -79.406960
# 47                                         Davisville  43.702765 -79.385769
# 48                        Moore Park, Summerhill East  43.690505 -79.382973
# 49  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686003 -79.402335

# %% [markdown]
# ## From here on we start analyzing the venues by category to finally cluster them and find simmilarities along the different Toronto neighbourhoods
#
# #### Start by defining the Foursquare credentials

# %%
#Foursquare APIs credentials

CLIENT_ID ='TN3QI1FNX0SSSESH0VI50FCPC3PPJWE0LV2BQRIEK25HGXYB'
CLIENT_SECRET = 'WMCOPGIROVIYJHSRB3NNL4M523FRSVF1W3CBKWEKG2N11GB2'
VERSION = '20180605'

# %%
#define function to get nearest Venues to each neighbourhood
import json

def getNearbyVenues(name, lat, long, radius = 700, LIMIT = 100):
    venues = []

    for name, lat, long in zip(name, lat, long):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            long, 
            radius, 
            LIMIT)
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        #import relevant data
        venues.append([(name, lat, long,
            venue['venue']['categories'][0]['name'],
            venue['venue']['name'],
            venue['venue']['location']['lat'],
            venue['venue']['location']['lng']) for venue in results])
        
    nearby_venues = pd.DataFrame(item for venue_list in venues for item in venue_list)
    nearby_venues.columns = ['Neighbourhood',
        'Neighbourhood Latitude',
        'Neighbourhood Longitude',
        'Venue Category',
        'Venue',
        'Venue Latitude',
        'Venue Longitude']
    
    return nearby_venues

# %%
#Create new df Toronto Venues

toronto_venues = getNearbyVenues(df_toronto['Neighbourhood'], df_toronto['Latitude'], df_toronto['Longitude'])

toronto_venues.head(10)
# Out:
#   Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0   The Beaches               43.676531                -79.29541
# 1   The Beaches               43.676531                -79.29541
# 2   The Beaches               43.676531                -79.29541
# 3   The Beaches               43.676531                -79.29541
# 4   The Beaches               43.676531                -79.29541
# 5   The Beaches               43.676531                -79.29541
# 6   The Beaches               43.676531                -79.29541
# 7   The Beaches               43.676531                -79.29541
# 8   The Beaches               43.676531                -79.29541
# 9   The Beaches               43.676531                -79.29541
#
#                   Venue Category                Venue  Venue Latitude  \
# 0                         Bakery    Beaches Bake Shop       43.680363
# 1  Vegetarian / Vegan Restaurant      Tori's Bakeshop       43.672114
# 2               Toy / Game Store      Mastermind Toys       43.671453
# 3                      Gastropub       The Beech Tree       43.680493
# 4                 Breakfast Spot         Beacher Cafe       43.671938
# 5              French Restaurant       Veloute Bistro       43.672267
# 6                            Bar      Castro's Lounge       43.671104
# 7            Japanese Restaurant          Yumei Sushi       43.671108
# 8                      Juice Bar     Sanna's Farmacia       43.670929
# 9                       Tea Room  Pippins Tea Company       43.670992
#
#    Venue Longitude
# 0       -79.289692
# 1       -79.290331
# 2       -79.293971
# 3       -79.288846
# 4       -79.291238
# 5       -79.289584
# 6       -79.295107
# 7       -79.295064
# 8       -79.295969
# 9       -79.295905

# %%
#Checking venues per neighbourhood

toronto_venues.groupby('Neighbourhood').count()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# Adelaide, King, Richmond                                               100
# Berczy Park                                                            100
# Brockton, Exhibition Place, Parkdale Village                           100
# Business reply mail Processing Centre969 Eastern                       100
# CN Tower, Bathurst Quay, Island airport, Harbou...                     100
# Cabbagetown, St. James Town                                             68
# Central Bay Street                                                     100
# Chinatown, Grange Park, Kensington Market                              100
# Christie                                                                71
# Church and Wellesley                                                   100
# Commerce Court, Victoria Hotel                                         100
# Davisville                                                              40
# Davisville North                                                        22
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                      19
# Design Exchange, Toronto Dominion Centre                               100
# Dovercourt Village, Dufferin                                            46
# First Canadian Place, Underground city                                 100
# Forest Hill North, Forest Hill West                                     12
# Harbord, University of Toronto                                          82
# Harbourfront East, Toronto Islands, Union Station                        4
# Harbourfront, Regent Park                                               90
# High Park, The Junction South                                           43
# Lawrence Park                                                            7
# Little Portugal, Trinity                                               100
# Moore Park, Summerhill East                                              7
# North Toronto West                                                      37
# Parkdale, Roncesvalles                                                  75
# Rosedale                                                                 6
# Roselawn                                                                 5
# Runnymede, Swansea                                                      52
# Ryerson, Garden District                                               100
# St. James Town                                                         100
# Stn A PO Boxes 25 The Esplanade                                        100
# Studio District                                                         74
# The Annex, North Midtown, Yorkville                                     44
# The Beaches                                                             31
# The Beaches West, India Bazaar                                          36
# The Danforth West, Riverdale                                            35
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# Adelaide, King, Richmond                                                100
# Berczy Park                                                             100
# Brockton, Exhibition Place, Parkdale Village                            100
# Business reply mail Processing Centre969 Eastern                        100
# CN Tower, Bathurst Quay, Island airport, Harbou...                      100
# Cabbagetown, St. James Town                                              68
# Central Bay Street                                                      100
# Chinatown, Grange Park, Kensington Market                               100
# Christie                                                                 71
# Church and Wellesley                                                    100
# Commerce Court, Victoria Hotel                                          100
# Davisville                                                               40
# Davisville North                                                         22
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                       19
# Design Exchange, Toronto Dominion Centre                                100
# Dovercourt Village, Dufferin                                             46
# First Canadian Place, Underground city                                  100
# Forest Hill North, Forest Hill West                                      12
# Harbord, University of Toronto                                           82
# Harbourfront East, Toronto Islands, Union Station                         4
# Harbourfront, Regent Park                                                90
# High Park, The Junction South                                            43
# Lawrence Park                                                             7
# Little Portugal, Trinity                                                100
# Moore Park, Summerhill East                                               7
# North Toronto West                                                       37
# Parkdale, Roncesvalles                                                   75
# Rosedale                                                                  6
# Roselawn                                                                  5
# Runnymede, Swansea                                                       52
# Ryerson, Garden District                                                100
# St. James Town                                                          100
# Stn A PO Boxes 25 The Esplanade                                         100
# Studio District                                                          74
# The Annex, North Midtown, Yorkville                                      44
# The Beaches                                                              31
# The Beaches West, India Bazaar                                           36
# The Danforth West, Riverdale                                             35
#
#                                                     Venue Category  Venue  \
# Neighbourhood
# Adelaide, King, Richmond                                       100    100
# Berczy Park                                                    100    100
# Brockton, Exhibition Place, Parkdale Village                   100    100
# Business reply mail Processing Centre969 Eastern               100    100
# CN Tower, Bathurst Quay, Island airport, Harbou...             100    100
# Cabbagetown, St. James Town                                     68     68
# Central Bay Street                                             100    100
# Chinatown, Grange Park, Kensington Market                      100    100
# Christie                                                        71     71
# Church and Wellesley                                           100    100
# Commerce Court, Victoria Hotel                                 100    100
# Davisville                                                      40     40
# Davisville North                                                22     22
# Deer Park, Forest Hill SE, Rathnelly, South Hil...              19     19
# Design Exchange, Toronto Dominion Centre                       100    100
# Dovercourt Village, Dufferin                                    46     46
# First Canadian Place, Underground city                         100    100
# Forest Hill North, Forest Hill West                             12     12
# Harbord, University of Toronto                                  82     82
# Harbourfront East, Toronto Islands, Union Station                4      4
# Harbourfront, Regent Park                                       90     90
# High Park, The Junction South                                   43     43
# Lawrence Park                                                    7      7
# Little Portugal, Trinity                                       100    100
# Moore Park, Summerhill East                                      7      7
# North Toronto West                                              37     37
# Parkdale, Roncesvalles                                          75     75
# Rosedale                                                         6      6
# Roselawn                                                         5      5
# Runnymede, Swansea                                              52     52
# Ryerson, Garden District                                       100    100
# St. James Town                                                 100    100
# Stn A PO Boxes 25 The Esplanade                                100    100
# Studio District                                                 74     74
# The Annex, North Midtown, Yorkville                             44     44
# The Beaches                                                     31     31
# The Beaches West, India Bazaar                                  36     36
# The Danforth West, Riverdale                                    35     35
#
#                                                     Venue Latitude  \
# Neighbourhood
# Adelaide, King, Richmond                                       100
# Berczy Park                                                    100
# Brockton, Exhibition Place, Parkdale Village                   100
# Business reply mail Processing Centre969 Eastern               100
# CN Tower, Bathurst Quay, Island airport, Harbou...             100
# Cabbagetown, St. James Town                                     68
# Central Bay Street                                             100
# Chinatown, Grange Park, Kensington Market                      100
# Christie                                                        71
# Church and Wellesley                                           100
# Commerce Court, Victoria Hotel                                 100
# Davisville                                                      40
# Davisville North                                                22
# Deer Park, Forest Hill SE, Rathnelly, South Hil...              19
# Design Exchange, Toronto Dominion Centre                       100
# Dovercourt Village, Dufferin                                    46
# First Canadian Place, Underground city                         100
# Forest Hill North, Forest Hill West                             12
# Harbord, University of Toronto                                  82
# Harbourfront East, Toronto Islands, Union Station                4
# Harbourfront, Regent Park                                       90
# High Park, The Junction South                                   43
# Lawrence Park                                                    7
# Little Portugal, Trinity                                       100
# Moore Park, Summerhill East                                      7
# North Toronto West                                              37
# Parkdale, Roncesvalles                                          75
# Rosedale                                                         6
# Roselawn                                                         5
# Runnymede, Swansea                                              52
# Ryerson, Garden District                                       100
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                100
# Studio District                                                 74
# The Annex, North Midtown, Yorkville                             44
# The Beaches                                                     31
# The Beaches West, India Bazaar                                  36
# The Danforth West, Riverdale                                    35
#
#                                                     Venue Longitude
# Neighbourhood
# Adelaide, King, Richmond                                        100
# Berczy Park                                                     100
# Brockton, Exhibition Place, Parkdale Village                    100
# Business reply mail Processing Centre969 Eastern                100
# CN Tower, Bathurst Quay, Island airport, Harbou...              100
# Cabbagetown, St. James Town                                      68
# Central Bay Street                                              100
# Chinatown, Grange Park, Kensington Market                       100
# Christie                                                         71
# Church and Wellesley                                            100
# Commerce Court, Victoria Hotel                                  100
# Davisville                                                       40
# Davisville North                                                 22
# Deer Park, Forest Hill SE, Rathnelly, South Hil...               19
# Design Exchange, Toronto Dominion Centre                        100
# Dovercourt Village, Dufferin                                     46
# First Canadian Place, Underground city                          100
# Forest Hill North, Forest Hill West                              12
# Harbord, University of Toronto                                   82
# Harbourfront East, Toronto Islands, Union Station                 4
# Harbourfront, Regent Park                                        90
# High Park, The Junction South                                    43
# Lawrence Park                                                     7
# Little Portugal, Trinity                                        100
# Moore Park, Summerhill East                                       7
# North Toronto West                                               37
# Parkdale, Roncesvalles                                           75
# Rosedale                                                          6
# Roselawn                                                          5
# Runnymede, Swansea                                               52
# Ryerson, Garden District                                        100
# St. James Town                                                  100
# Stn A PO Boxes 25 The Esplanade                                 100
# Studio District                                                  74
# The Annex, North Midtown, Yorkville                              44
# The Beaches                                                      31
# The Beaches West, India Bazaar                                   36
# The Danforth West, Riverdale                                     35

# %%
#Checking some statistics

toronto_venues.describe(include='all')
# Out:
#                    Neighbourhood  Neighbourhood Latitude  \
# count                       2406             2406.000000
# unique                        38                     NaN
# top     Adelaide, King, Richmond                     NaN
# freq                         100                     NaN
# mean                         NaN               43.657529
# std                          NaN                0.015769
# min                          NaN               43.623470
# 25%                          NaN               43.648399
# 50%                          NaN               43.651210
# 75%                          NaN               43.663110
# max                          NaN               43.728135
#
#         Neighbourhood Longitude Venue Category      Venue  Venue Latitude  \
# count               2406.000000           2406       2406     2406.000000
# unique                      NaN            257       1501             NaN
# top                         NaN    Coffee Shop  Starbucks             NaN
# freq                        NaN            193         68             NaN
# mean                 -79.391008            NaN        NaN       43.657322
# std                    0.030683            NaN        NaN        0.015455
# min                  -79.475057            NaN        NaN       43.623140
# 25%                  -79.402335            NaN        NaN       43.648292
# 50%                  -79.384930            NaN        NaN       43.651706
# 75%                  -79.378180            NaN        NaN       43.663150
# max                  -79.295410            NaN        NaN       43.733043
#
#         Venue Longitude
# count       2406.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean         -79.391135
# std            0.030695
# min          -79.483683
# 25%          -79.402996
# 50%          -79.385607
# 75%          -79.378902
# max          -79.288791

# %% [markdown]
# ## Analyzing the data
#
# #### We start by one hot encoding the venue types and sorting it to find the most common venue type

# %%
#hot encode

one_hot_toronto = pd.get_dummies(toronto_venues[['Venue Category']], prefix='', prefix_sep='')
one_hot_toronto['Neighbourhood'] = toronto_venues['Neighbourhood']
columns = np.concatenate((['Neighbourhood'], one_hot_toronto.columns[:-1].values))
one_hot_toronto = one_hot_toronto[columns]

# %%
#normalize encoding by obtaining mean grouping by neighbourhood

toronto_venues_by_n = one_hot_toronto.groupby('Neighbourhood').mean()
toronto_venues_by_n.reset_index(inplace=True)
toronto_venues_by_n.head(10)
# Out:
#                                        Neighbourhood  Accessories Store  \
# 0                           Adelaide, King, Richmond               0.00
# 1                                        Berczy Park               0.00
# 2       Brockton, Exhibition Place, Parkdale Village               0.01
# 3   Business reply mail Processing Centre969 Eastern               0.00
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...               0.00
# 5                        Cabbagetown, St. James Town               0.00
# 6                                 Central Bay Street               0.00
# 7          Chinatown, Grange Park, Kensington Market               0.00
# 8                                           Christie               0.00
# 9                               Church and Wellesley               0.00
#
#    Adult Boutique  Afghan Restaurant  African Restaurant  American Restaurant  \
# 0            0.00               0.00                 0.0             0.030000
# 1            0.00               0.00                 0.0             0.000000
# 2            0.00               0.00                 0.0             0.000000
# 3            0.00               0.00                 0.0             0.030000
# 4            0.00               0.00                 0.0             0.010000
# 5            0.00               0.00                 0.0             0.014706
# 6            0.00               0.00                 0.0             0.020000
# 7            0.01               0.00                 0.0             0.000000
# 8            0.00               0.00                 0.0             0.014085
# 9            0.01               0.01                 0.0             0.020000
#
#    Animal Shelter  Antique Shop  Arepa Restaurant  Art Gallery     ...       \
# 0             0.0           0.0              0.00         0.01     ...
# 1             0.0           0.0              0.00         0.02     ...
# 2             0.0           0.0              0.00         0.04     ...
# 3             0.0           0.0              0.00         0.01     ...
# 4             0.0           0.0              0.00         0.00     ...
# 5             0.0           0.0              0.00         0.00     ...
# 6             0.0           0.0              0.00         0.02     ...
# 7             0.0           0.0              0.01         0.01     ...
# 8             0.0           0.0              0.00         0.00     ...
# 9             0.0           0.0              0.00         0.00     ...
#
#    University  Vegetarian / Vegan Restaurant  Video Game Store  Video Store  \
# 0        0.00                       0.010000              0.00         0.00
# 1        0.00                       0.000000              0.00         0.00
# 2        0.00                       0.030000              0.00         0.00
# 3        0.00                       0.010000              0.00         0.00
# 4        0.00                       0.000000              0.00         0.00
# 5        0.00                       0.000000              0.00         0.00
# 6        0.01                       0.020000              0.00         0.00
# 7        0.01                       0.060000              0.00         0.00
# 8        0.00                       0.014085              0.00         0.00
# 9        0.00                       0.010000              0.01         0.01
#
#    Vietnamese Restaurant  Wine Bar  Wine Shop  Wings Joint  Women's Store  \
# 0                   0.00      0.01       0.00          0.0           0.01
# 1                   0.00      0.00       0.00          0.0           0.00
# 2                   0.00      0.00       0.00          0.0           0.00
# 3                   0.00      0.00       0.00          0.0           0.00
# 4                   0.00      0.00       0.01          0.0           0.00
# 5                   0.00      0.00       0.00          0.0           0.00
# 6                   0.00      0.00       0.00          0.0           0.00
# 7                   0.03      0.01       0.00          0.0           0.00
# 8                   0.00      0.00       0.00          0.0           0.00
# 9                   0.01      0.00       0.00          0.0           0.00
#
#    Yoga Studio
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.01
# 4         0.01
# 5         0.00
# 6         0.01
# 7         0.02
# 8         0.00
# 9         0.02
#
# [10 rows x 258 columns]

# %% [markdown]
# #### Now we try to obtain a table with the n-th most common venue type per neighbourhood

# %%
#We need to sort for each row horizontally the columns to obtain a ranking

#Define function to initialize columns

def columns_rank(n):
    
    item = []
    #max allowed n value = 20
    aux = ['st','nd','rd']
    for i in range(n):
        try:
            item.append('{}{} Most Common Venue'.format(i + 1, aux[i]))
        except:
            item.append('{}th Most Common Venue'.format(i + 1))
    
    return item


#Define function to get top n venues

def top_venues(df, top_n = 10):

    top = []
    for i in range(df.shape[0]):
        row = df.iloc[i,1:]
        row.sort_values(ascending = False, inplace=True)
        row = row[:top_n]
        top.append(np.array(row.index))
        
    top_df = pd.DataFrame(top)
    top_df['Neighbourhood'] = df['Neighbourhood']
    columns = np.concatenate((['Neighbourhood'], top_df.columns[:-1].values))
    top_df = top_df[columns]
    top_df.columns=np.concatenate((['Neighbourhood'], columns_rank(top_n)))
    
    return pd.DataFrame(top_df)

top_venues_df = top_venues(toronto_venues_by_n)
top_venues_df.head(10)
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2       Brockton, Exhibition Place, Parkdale Village           Coffee Shop
# 3   Business reply mail Processing Centre969 Eastern           Coffee Shop
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...           Coffee Shop
# 5                        Cabbagetown, St. James Town            Restaurant
# 6                                 Central Bay Street           Coffee Shop
# 7          Chinatown, Grange Park, Kensington Market                  Café
# 8                                           Christie     Korean Restaurant
# 9                               Church and Wellesley           Coffee Shop
#
#            2nd Most Common Venue 3rd Most Common Venue  \
# 0                          Hotel                  Café
# 1                          Hotel            Restaurant
# 2                            Bar                  Café
# 3                           Café            Restaurant
# 4                     Restaurant    Italian Restaurant
# 5                    Coffee Shop                  Café
# 6                 Clothing Store            Restaurant
# 7  Vegetarian / Vegan Restaurant    Chinese Restaurant
# 8                  Grocery Store           Coffee Shop
# 9            Japanese Restaurant          Burger Joint
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0              Steakhouse         Deli / Bodega            Restaurant
# 1                    Café          Cocktail Bar    Italian Restaurant
# 2  Furniture / Home Store           Art Gallery            Restaurant
# 3              Steakhouse                 Hotel   American Restaurant
# 4                    Café                   Gym                  Park
# 5                    Park           Pizza Place                   Pub
# 6      Chinese Restaurant    Italian Restaurant      Ramen Restaurant
# 7     Dumpling Restaurant                Bakery                   Bar
# 8       Indian Restaurant           Pizza Place                  Café
# 9              Restaurant               Gay Bar                 Diner
#
#        7th Most Common Venue          8th Most Common Venue  \
# 0             Breakfast Spot                      Gastropub
# 1        Japanese Restaurant                            Pub
# 2                     Bakery  Vegetarian / Vegan Restaurant
# 3                        Bar                Thai Restaurant
# 4                     Bakery                 Sandwich Place
# 5         Italian Restaurant              Indian Restaurant
# 6  Middle Eastern Restaurant                Thai Restaurant
# 7         Mexican Restaurant          Vietnamese Restaurant
# 8                       Park                          Diner
# 9                       Café               Sushi Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0   American Restaurant    Japanese Restaurant
# 1                Bakery          Deli / Bodega
# 2     Indian Restaurant           Cocktail Bar
# 3             Gastropub                Theater
# 4                   Spa    Japanese Restaurant
# 5                 Diner                 Bakery
# 6               Theater                    Spa
# 7           Coffee Shop       Ramen Restaurant
# 8        Ice Cream Shop     Mexican Restaurant
# 9             Bookstore         Breakfast Spot

# %% [markdown]
# ## Machine Learning k-means Clustering
#
# #### We execute the k-means algorithm to cluster the neighbourhoods and map them

# %%
#Import KMeans library
from sklearn.cluster import KMeans

#Initialize number of clusters and run KMeans

n_clusters = 6
toronto_cluster_df = toronto_venues_by_n.drop('Neighbourhood', axis = 1)

kmeans = KMeans(n_clusters=n_clusters, init='k-means++',n_init=12)
kmeans.fit(toronto_cluster_df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=12, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#Merge complete Toronto Center dataframe with top10 venues dataframe

top_venues_df['Cluster labels'] = kmeans.labels_
columns = np.concatenate((['Cluster labels'], top_venues_df.columns[:-1].values))
top_venues_df = top_venues_df[columns]

top_venues_df.head(15)
# Out:
#     Cluster labels                                      Neighbourhood  \
# 0                1                           Adelaide, King, Richmond
# 1                1                                        Berczy Park
# 2                1       Brockton, Exhibition Place, Parkdale Village
# 3                1   Business reply mail Processing Centre969 Eastern
# 4                1  CN Tower, Bathurst Quay, Island airport, Harbo...
# 5                5                        Cabbagetown, St. James Town
# 6                1                                 Central Bay Street
# 7                5          Chinatown, Grange Park, Kensington Market
# 8                5                                           Christie
# 9                1                               Church and Wellesley
# 10               1                     Commerce Court, Victoria Hotel
# 11               5                                         Davisville
# 12               5                                   Davisville North
# 13               5  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 14               1           Design Exchange, Toronto Dominion Centre
#
#    1st Most Common Venue          2nd Most Common Venue 3rd Most Common Venue  \
# 0            Coffee Shop                          Hotel                  Café
# 1            Coffee Shop                          Hotel            Restaurant
# 2            Coffee Shop                            Bar                  Café
# 3            Coffee Shop                           Café            Restaurant
# 4            Coffee Shop                     Restaurant    Italian Restaurant
# 5             Restaurant                    Coffee Shop                  Café
# 6            Coffee Shop                 Clothing Store            Restaurant
# 7                   Café  Vegetarian / Vegan Restaurant    Chinese Restaurant
# 8      Korean Restaurant                  Grocery Store           Coffee Shop
# 9            Coffee Shop            Japanese Restaurant          Burger Joint
# 10           Coffee Shop                          Hotel                  Café
# 11           Coffee Shop                   Dessert Shop        Sandwich Place
# 12               Brewery                   Dessert Shop          Burger Joint
# 13           Coffee Shop                   Skating Rink                   Pub
# 14           Coffee Shop                           Café                 Hotel
#
#      4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0               Steakhouse         Deli / Bodega            Restaurant
# 1                     Café          Cocktail Bar    Italian Restaurant
# 2   Furniture / Home Store           Art Gallery            Restaurant
# 3               Steakhouse                 Hotel   American Restaurant
# 4                     Café                   Gym                  Park
# 5                     Park           Pizza Place                   Pub
# 6       Chinese Restaurant    Italian Restaurant      Ramen Restaurant
# 7      Dumpling Restaurant                Bakery                   Bar
# 8        Indian Restaurant           Pizza Place                  Café
# 9               Restaurant               Gay Bar                 Diner
# 10              Restaurant   American Restaurant            Steakhouse
# 11        Sushi Restaurant                   Gym              Pharmacy
# 12                    Café           Pizza Place        Breakfast Spot
# 13             Pizza Place   Fried Chicken Joint        Sandwich Place
# 14              Steakhouse            Restaurant   American Restaurant
#
#         7th Most Common Venue          8th Most Common Venue  \
# 0              Breakfast Spot                      Gastropub
# 1         Japanese Restaurant                            Pub
# 2                      Bakery  Vegetarian / Vegan Restaurant
# 3                         Bar                Thai Restaurant
# 4                      Bakery                 Sandwich Place
# 5          Italian Restaurant              Indian Restaurant
# 6   Middle Eastern Restaurant                Thai Restaurant
# 7          Mexican Restaurant          Vietnamese Restaurant
# 8                        Park                          Diner
# 9                        Café               Sushi Restaurant
# 10                  Gastropub            Japanese Restaurant
# 11                       Café             Seafood Restaurant
# 12          Food & Drink Shop               Sushi Restaurant
# 13           Sushi Restaurant                    Supermarket
# 14              Deli / Bodega                      Gastropub
#
#    9th Most Common Venue 10th Most Common Venue
# 0    American Restaurant    Japanese Restaurant
# 1                 Bakery          Deli / Bodega
# 2      Indian Restaurant           Cocktail Bar
# 3              Gastropub                Theater
# 4                    Spa    Japanese Restaurant
# 5                  Diner                 Bakery
# 6                Theater                    Spa
# 7            Coffee Shop       Ramen Restaurant
# 8         Ice Cream Shop     Mexican Restaurant
# 9              Bookstore         Breakfast Spot
# 10         Deli / Bodega               Beer Bar
# 11           Pizza Place     Italian Restaurant
# 12               Dog Run         Sandwich Place
# 13            Bagel Shop               Boutique
# 14                   Gym       Asian Restaurant

# %%
toronto_merged = df_toronto

toronto_merged = toronto_merged.join(top_venues_df.set_index('Neighbourhood'), on='Neighbourhood')
toronto_merged.reset_index(drop=True,inplace=True)
toronto_merged.head(10)
# Out:
#   Postalcode          Borough  \
# 0        M4E     East Toronto
# 1        M4K     East Toronto
# 2        M4L     East Toronto
# 3        M4M     East Toronto
# 4        M4N  Central Toronto
# 5        M4P  Central Toronto
# 6        M4R  Central Toronto
# 7        M4S  Central Toronto
# 8        M4T  Central Toronto
# 9        M4V  Central Toronto
#
#                                        Neighbourhood   Latitude  Longitude  \
# 0                                        The Beaches  43.676531 -79.295410
# 1                       The Danforth West, Riverdale  43.683262 -79.355120
# 2                     The Beaches West, India Bazaar  43.667985 -79.314642
# 3                                    Studio District  43.662766 -79.334830
# 4                                      Lawrence Park  43.728135 -79.387090
# 5                                   Davisville North  43.712755 -79.388514
# 6                                 North Toronto West  43.714523 -79.406960
# 7                                         Davisville  43.702765 -79.385769
# 8                        Moore Park, Summerhill East  43.690505 -79.382973
# 9  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686003 -79.402335
#
#    Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               5             Pet Store           Pizza Place
# 1               5      Greek Restaurant        Ice Cream Shop
# 2               5             Pet Store           Coffee Shop
# 3               5           Coffee Shop                Bakery
# 4               0            Restaurant              Bus Line
# 5               5               Brewery          Dessert Shop
# 6               5   Sporting Goods Shop                  Café
# 7               5           Coffee Shop          Dessert Shop
# 8               3                  Park       Thai Restaurant
# 9               5           Coffee Shop          Skating Rink
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Restaurant                   Bar              Tea Room
# 1            Restaurant                  Café           Yoga Studio
# 2               Brewery                Bakery  Fast Food Restaurant
# 3                  Café                   Bar                 Diner
# 4             Bookstore  Gym / Fitness Center                  Park
# 5          Burger Joint                  Café           Pizza Place
# 6        Clothing Store           Coffee Shop            Restaurant
# 7        Sandwich Place      Sushi Restaurant                   Gym
# 8            Playground                   Gym         Grocery Store
# 9                   Pub           Pizza Place   Fried Chicken Joint
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                Church            Nail Salon          Neighborhood
# 1                   Pub             Juice Bar           Coffee Shop
# 2        Sandwich Place                  Café                  Park
# 3        Sandwich Place    Italian Restaurant   American Restaurant
# 4                  Café           Coffee Shop     Elementary School
# 5        Breakfast Spot     Food & Drink Shop      Sushi Restaurant
# 6            Steakhouse                   Spa        Sandwich Place
# 7              Pharmacy                  Café    Seafood Restaurant
# 8          Tennis Court   Dumpling Restaurant        Discount Store
# 9        Sandwich Place      Sushi Restaurant           Supermarket
#
#   9th Most Common Venue 10th Most Common Venue
# 0             Juice Bar      French Restaurant
# 1           Tailor Shop         Discount Store
# 2                   Gym                  Diner
# 3  Fast Food Restaurant            Pizza Place
# 4            Donut Shop    Dumpling Restaurant
# 5               Dog Run         Sandwich Place
# 6    Salon / Barbershop     Chinese Restaurant
# 7           Pizza Place     Italian Restaurant
# 8              Dive Bar                Dog Run
# 9            Bagel Shop               Boutique

# %% [markdown]
# ## Map the resulting clusters
#
# #### We start mapping the clusters acoording to their neighbourhoods

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

#Get average coordinates for Toronto Center
coord = np.array(df_toronto[['Latitude','Longitude']].mean(axis = 0))

loc_lat = coord[0]
loc_lon = coord[1]


colors_array = cm.rainbow(np.linspace(0, 1, n_clusters))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#Map clusters
toronto_map = folium.Map(location=[loc_lat, loc_lon], zoom_start=12)

for borough, name, lat, lon, cluster in zip(toronto_merged['Borough'], toronto_merged['Neighbourhood'],toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Cluster labels']):
    label = folium.Popup(str(name) + ', ' + str(borough) + ' | Cluster: ' + str(cluster+1))
    folium.CircleMarker([lat,lon], radius=5, popup=label, color=rainbow[cluster-1],fill=True,fill_color=rainbow[cluster-1],fill_opacity=0.7).add_to(toronto_map)
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore each cluster
#
# #### Now we can explore each cluster by showing its top 10 venue categories. The map helps us to know geographically where they are mostly located. We can clearly note a pattern in this.

# %% [markdown]
# ### Cluster 1

# %%
toronto_merged[toronto_merged['Cluster labels']==0]
# Out:
#    Postalcode          Borough                        Neighbourhood  \
# 4         M4N  Central Toronto                        Lawrence Park
# 23        M5P  Central Toronto  Forest Hill North, Forest Hill West
#
#      Latitude  Longitude  Cluster labels 1st Most Common Venue  \
# 4   43.728135 -79.387090               0            Restaurant
# 23  43.694785 -79.414405               0                  Bank
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4               Bus Line             Bookstore  Gym / Fitness Center
# 23        Ice Cream Shop              Bus Line                  Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4                   Park                  Café           Coffee Shop
# 23             Bookstore    Salon / Barbershop                Bakery
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 4      Elementary School            Donut Shop    Dumpling Restaurant
# 23           Coffee Shop                  Park           Burger Joint

# %% [markdown]
# ### Cluster 2

# %%
toronto_merged[toronto_merged['Cluster labels']==1]
# Out:
#    Postalcode           Borough  \
# 12        M4Y  Downtown Toronto
# 13        M5A  Downtown Toronto
# 14        M5B  Downtown Toronto
# 15        M5C  Downtown Toronto
# 16        M5E  Downtown Toronto
# 17        M5G  Downtown Toronto
# 18        M5H  Downtown Toronto
# 20        M5K  Downtown Toronto
# 21        M5L  Downtown Toronto
# 24        M5R   Central Toronto
# 27        M5V  Downtown Toronto
# 28        M5W  Downtown Toronto
# 29        M5X  Downtown Toronto
# 33        M6K      West Toronto
# 36        M6S      West Toronto
# 37        M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude  \
# 12                               Church and Wellesley  43.666585 -79.381302
# 13                          Harbourfront, Regent Park  43.655120 -79.362640
# 14                           Ryerson, Garden District  43.657363 -79.378180
# 15                                     St. James Town  43.651210 -79.375481
# 16                                        Berczy Park  43.645160 -79.373675
# 17                                 Central Bay Street  43.656091 -79.384930
# 18                           Adelaide, King, Richmond  43.649700 -79.382582
# 20           Design Exchange, Toronto Dominion Centre  43.648399 -79.383939
# 21                     Commerce Court, Victoria Hotel  43.648395 -79.378865
# 24                The Annex, North Midtown, Yorkville  43.674840 -79.403698
# 27  CN Tower, Bathurst Quay, Island airport, Harbo...  43.640815 -79.399538
# 28                    Stn A PO Boxes 25 The Esplanade  43.648690 -79.385440
# 29             First Canadian Place, Underground city  43.648336 -79.384462
# 33       Brockton, Exhibition Place, Parkdale Village  43.639410 -79.425436
# 36                                 Runnymede, Swansea  43.649570 -79.475057
# 37   Business reply mail Processing Centre969 Eastern  43.648690 -79.385440
#
#     Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 12               1           Coffee Shop   Japanese Restaurant
# 13               1           Coffee Shop                  Café
# 14               1           Coffee Shop        Clothing Store
# 15               1           Coffee Shop                  Café
# 16               1           Coffee Shop                 Hotel
# 17               1           Coffee Shop        Clothing Store
# 18               1           Coffee Shop                 Hotel
# 20               1           Coffee Shop                  Café
# 21               1           Coffee Shop                 Hotel
# 24               1           Coffee Shop                  Café
# 27               1           Coffee Shop            Restaurant
# 28               1           Coffee Shop                  Café
# 29               1           Coffee Shop                  Café
# 33               1           Coffee Shop                   Bar
# 36               1           Coffee Shop                  Café
# 37               1           Coffee Shop                  Café
#
#    3rd Most Common Venue   4th Most Common Venue     5th Most Common Venue  \
# 12          Burger Joint              Restaurant                   Gay Bar
# 13                  Park      Italian Restaurant                       Pub
# 14            Restaurant                Tea Room                      Café
# 15            Restaurant                   Hotel                    Bakery
# 16            Restaurant                    Café              Cocktail Bar
# 17            Restaurant      Chinese Restaurant        Italian Restaurant
# 18                  Café              Steakhouse             Deli / Bodega
# 20                 Hotel              Steakhouse                Restaurant
# 21                  Café              Restaurant       American Restaurant
# 24        Sandwich Place      Italian Restaurant  Mediterranean Restaurant
# 27    Italian Restaurant                    Café                       Gym
# 28            Restaurant              Steakhouse                     Hotel
# 29                 Hotel              Steakhouse                Restaurant
# 33                  Café  Furniture / Home Store               Art Gallery
# 36                Bakery                     Pub          Sushi Restaurant
# 37            Restaurant              Steakhouse                     Hotel
#
#    6th Most Common Venue      7th Most Common Venue  \
# 12                 Diner                       Café
# 13                Bakery       Gym / Fitness Center
# 14      Ramen Restaurant                Pizza Place
# 15    Italian Restaurant             Breakfast Spot
# 16    Italian Restaurant        Japanese Restaurant
# 17      Ramen Restaurant  Middle Eastern Restaurant
# 18            Restaurant             Breakfast Spot
# 20   American Restaurant              Deli / Bodega
# 21            Steakhouse                  Gastropub
# 24           Pizza Place          French Restaurant
# 27                  Park                     Bakery
# 28   American Restaurant                        Bar
# 29                   Gym            Thai Restaurant
# 33            Restaurant                     Bakery
# 36           Pizza Place         Falafel Restaurant
# 37   American Restaurant                        Bar
#
#             8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12               Sushi Restaurant             Bookstore         Breakfast Spot
# 13                        Theater            Restaurant         Breakfast Spot
# 14      Middle Eastern Restaurant   Japanese Restaurant     Italian Restaurant
# 15            American Restaurant    Seafood Restaurant         Cosmetics Shop
# 16                            Pub                Bakery          Deli / Bodega
# 17                Thai Restaurant               Theater                    Spa
# 18                      Gastropub   American Restaurant    Japanese Restaurant
# 20                      Gastropub                   Gym       Asian Restaurant
# 21            Japanese Restaurant         Deli / Bodega               Beer Bar
# 24                 History Museum     Jewish Restaurant                   Park
# 27                 Sandwich Place                   Spa    Japanese Restaurant
# 28                Thai Restaurant             Gastropub                Theater
# 29            American Restaurant         Deli / Bodega                    Pub
# 33  Vegetarian / Vegan Restaurant     Indian Restaurant           Cocktail Bar
# 36      Latin American Restaurant             Bookstore           Dessert Shop
# 37                Thai Restaurant             Gastropub                Theater

# %% [markdown]
# ### Cluster 3

# %%
toronto_merged[toronto_merged['Cluster labels']==2]
# Out:
#    Postalcode          Borough Neighbourhood   Latitude  Longitude  \
# 22        M5N  Central Toronto      Roselawn  43.711941  -79.41912
#
#     Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 22               2            Playground      Business Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 22             Pet Store                Garden    Falafel Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 22                  Farm           Event Space  Ethiopian Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 22               Dog Run         Farmers Market

# %% [markdown]
# ### Cluster 4

# %%
toronto_merged[toronto_merged['Cluster labels']==3]
# Out:
#    Postalcode           Borough                Neighbourhood   Latitude  \
# 8         M4T   Central Toronto  Moore Park, Summerhill East  43.690505
# 10        M4W  Downtown Toronto                     Rosedale  43.681960
#
#     Longitude  Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 8  -79.382973               3                  Park       Thai Restaurant
# 10 -79.378445               3                  Park         Grocery Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8             Playground                   Gym         Grocery Store
# 10            Playground           Candy Store                  Bank
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8           Tennis Court   Dumpling Restaurant        Discount Store
# 10     Electronics Store      Doner Restaurant            Donut Shop
#
#    9th Most Common Venue       10th Most Common Venue
# 8               Dive Bar                      Dog Run
# 10   Dumpling Restaurant  Eastern European Restaurant

# %% [markdown]
# ### Cluster 5

# %%
toronto_merged[toronto_merged['Cluster labels']==4]
# Out:
#    Postalcode           Borough  \
# 19        M5J  Downtown Toronto
#
#                                         Neighbourhood  Latitude  Longitude  \
# 19  Harbourfront East, Toronto Islands, Union Station  43.62347 -79.393979
#
#     Cluster labels 1st Most Common Venue 2nd Most Common Venue  \
# 19               4      Sculpture Garden       Harbor / Marina
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19         Boat or Ferry           Music Venue    Falafel Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19                  Farm        Farmers Market           Event Space
#
#    9th Most Common Venue 10th Most Common Venue
# 19              Dive Bar   Ethiopian Restaurant

# %% [markdown]
# ### Cluster 6

# %%
toronto_merged[toronto_merged['Cluster labels']==5]
# Out:
#    Postalcode           Borough  \
# 0         M4E      East Toronto
# 1         M4K      East Toronto
# 2         M4L      East Toronto
# 3         M4M      East Toronto
# 5         M4P   Central Toronto
# 6         M4R   Central Toronto
# 7         M4S   Central Toronto
# 9         M4V   Central Toronto
# 11        M4X  Downtown Toronto
# 25        M5S  Downtown Toronto
# 26        M5T  Downtown Toronto
# 30        M6G  Downtown Toronto
# 31        M6H      West Toronto
# 32        M6J      West Toronto
# 34        M6P      West Toronto
# 35        M6R      West Toronto
#
#                                         Neighbourhood   Latitude  Longitude  \
# 0                                         The Beaches  43.676531 -79.295410
# 1                        The Danforth West, Riverdale  43.683262 -79.355120
# 2                      The Beaches West, India Bazaar  43.667985 -79.314642
# 3                                     Studio District  43.662766 -79.334830
# 5                                    Davisville North  43.712755 -79.388514
# 6                                  North Toronto West  43.714523 -79.406960
# 7                                          Davisville  43.702765 -79.385769
# 9   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686003 -79.402335
# 11                        Cabbagetown, St. James Town  43.668155 -79.366600
# 25                     Harbord, University of Toronto  43.663110 -79.401801
# 26          Chinatown, Grange Park, Kensington Market  43.653525 -79.397231
# 30                                           Christie  43.668693 -79.420710
# 31                       Dovercourt Village, Dufferin  43.665087 -79.438705
# 32                           Little Portugal, Trinity  43.648525 -79.417757
# 34                      High Park, The Junction South  43.659730 -79.462812
# 35                             Parkdale, Roncesvalles  43.647870 -79.449762
#
#     Cluster labels 1st Most Common Venue          2nd Most Common Venue  \
# 0                5             Pet Store                    Pizza Place
# 1                5      Greek Restaurant                 Ice Cream Shop
# 2                5             Pet Store                    Coffee Shop
# 3                5           Coffee Shop                         Bakery
# 5                5               Brewery                   Dessert Shop
# 6                5   Sporting Goods Shop                           Café
# 7                5           Coffee Shop                   Dessert Shop
# 9                5           Coffee Shop                   Skating Rink
# 11               5            Restaurant                    Coffee Shop
# 25               5           Coffee Shop                           Café
# 26               5                  Café  Vegetarian / Vegan Restaurant
# 30               5     Korean Restaurant                  Grocery Store
# 31               5                   Bar                    Coffee Shop
# 32               5                   Bar                    Coffee Shop
# 34               5     Convenience Store                            Bar
# 35               5           Coffee Shop                         Bakery
#
#    3rd Most Common Venue 4th Most Common Venue        5th Most Common Venue  \
# 0    Japanese Restaurant                   Bar                     Tea Room
# 1             Restaurant                  Café                  Yoga Studio
# 2                Brewery                Bakery         Fast Food Restaurant
# 3                   Café                   Bar                        Diner
# 5           Burger Joint                  Café                  Pizza Place
# 6         Clothing Store           Coffee Shop                   Restaurant
# 7         Sandwich Place      Sushi Restaurant                          Gym
# 9                    Pub           Pizza Place          Fried Chicken Joint
# 11                  Café                  Park                  Pizza Place
# 25                   Bar            Restaurant                    Bookstore
# 26    Chinese Restaurant   Dumpling Restaurant                       Bakery
# 30           Coffee Shop     Indian Restaurant                  Pizza Place
# 31                Bakery           Supermarket                         Café
# 32                  Café            Restaurant                 Cocktail Bar
# 34       Thai Restaurant        Sandwich Place           Mexican Restaurant
# 35      Sushi Restaurant                  Café  Eastern European Restaurant
#
#    6th Most Common Venue 7th Most Common Venue  8th Most Common Venue  \
# 0                 Church            Nail Salon           Neighborhood
# 1                    Pub             Juice Bar            Coffee Shop
# 2         Sandwich Place                  Café                   Park
# 3         Sandwich Place    Italian Restaurant    American Restaurant
# 5         Breakfast Spot     Food & Drink Shop       Sushi Restaurant
# 6             Steakhouse                   Spa         Sandwich Place
# 7               Pharmacy                  Café     Seafood Restaurant
# 9         Sandwich Place      Sushi Restaurant            Supermarket
# 11                   Pub    Italian Restaurant      Indian Restaurant
# 25      Sushi Restaurant   Japanese Restaurant                 Bakery
# 26                   Bar    Mexican Restaurant  Vietnamese Restaurant
# 30                  Café                  Park                  Diner
# 31          Cocktail Bar    Mexican Restaurant               Pharmacy
# 32    Italian Restaurant      Asian Restaurant               Wine Bar
# 34                  Café           Pizza Place          Metro Station
# 35     Food & Drink Shop              Pharmacy             Restaurant
#
#             9th Most Common Venue 10th Most Common Venue
# 0                       Juice Bar      French Restaurant
# 1                     Tailor Shop         Discount Store
# 2                             Gym                  Diner
# 3            Fast Food Restaurant            Pizza Place
# 5                         Dog Run         Sandwich Place
# 6              Salon / Barbershop     Chinese Restaurant
# 7                     Pizza Place     Italian Restaurant
# 9                      Bagel Shop               Boutique
# 11                          Diner                 Bakery
# 25              Electronics Store            Music Venue
# 26                    Coffee Shop       Ramen Restaurant
# 30                 Ice Cream Shop     Mexican Restaurant
# 31                    Music Venue         Sandwich Place
# 32  Vegetarian / Vegan Restaurant                 Bakery
# 34                     Soup Place   Fast Food Restaurant
# 35                 Breakfast Spot        Thai Restaurant

# %% [markdown]
# ## Conclusion
#
# We can name the 6 clusters as follows:
#
# 1. __Cluster 1__: Financial Center and Bus Stations
# 1. __Cluster 2__: Coffee and bars
# 1. __Cluster 3__: Business Center
# 1. __Cluster 4__: Park and Playground
# 1. __Cluster 5__: Harbour and airport
# 1. __Cluster 6__: Restaurant
#
# Geographically we can conclude that any financial centers, bookstores, gym and bus lines can be found in two zones in Central Toronto, northwards Downtown Toronto. Restaurants are mainly distributed evenly north, east and west of Downtown Toronto mainly, but remains grouped near each other. Coffee shops and nightlife remains in Downtown Toronto. The business center is northwest and we can easily locate airport and harbours south of Downtown Toronto. Finally northbound Downtown Toronto we can find parks and playground sites, very near.
